# %% [markdown]
# # Setup do Código

# %% [markdown]
# Aqui o espaço para setar todos as variáveis para importar planilha

# %%
# Colocar Caminho da Pasta, que armazena os Excels de Consulta (usar '/', para o caminho)
PATH = './src'
CLIENT_PATH = './src/Clientes'

# Inserir Nome do Excel, com a extensão
portfolioCliente = 'Portfolio Global - KING.xlsx'

databaseFundos = 'New_query_2023_11_16 (1).xlsx'
historicoBenchmarks = 'arvore_classificacao_insper.xlsx'


# Limite de Tracking Error de Acordo com o Perfil de Risco do Investidor
perfilRisco = 1.1 # em porcentagem [%]

# Quantidade de Aplicações que vão ser Rebalanceadas
nAplicacoes = 4

# %% [markdown]
# <br>

# %% [markdown]
# ---

# %% [markdown]
# <br>

# %% [markdown]
# # Rebalanceamento de Carteira

# %% [markdown]
# ## Importando Bibliotecas

# %% [markdown]
# Bibliotecas Importantes usadas para o Código
# - OS: pode criar pastas e arquivos no sistema
# - Math: Usada para cálculos
# - Locale: Importar dados de formatação por região de números
# - Numpy: Processamento de Matrizes e Arrays
# - Pandas: Manipulação de Dataframes, e planilhas de Excel
# - Openpyxl: Leitura e Escrita de Excels
# - Scikit-Image (skimage): Processamento de Imagens (processamento de planilhas)
# - Unidecode: Decodar certos Carácteres
# - Scipy (scipy.optimize): Serve para Minimar a Funcão Objetivo
# - Plyer (notification): Manda Notificação pelo Computador

# %%
import os
import math
import locale
import numpy as np
import pandas as pd
import openpyxl as xl 
from skimage.measure import label, regionprops
from unidecode import unidecode
from scipy.optimize import minimize
from plyer import notification

# Setups das Bibliotecas
pd.options.mode.chained_assignment = None  # default='warn'
locale.setlocale(locale.LC_ALL, 'pt-BR.utf-8')
# Out:
# 'pt-BR.utf-8'

# %% [markdown]
# ## Leitura dos Excels e Planilhas:

# %% [markdown]
# Função para ler e receber os nomes de cada planilha dentro do excel

# %%
# Recebe Caminho do Arquivo, e Nome do Arquivo

def getSheetNames(path, file):
    excel_file = f'{path}/{file}'
    wb = xl.load_workbook(excel_file)
    
    if len(wb.sheetnames) == 1:
        return [wb.sheetnames[0]]
    else:
        return wb.sheetnames

# %%
# Carteira Portfólio Cliente
nameClient = getSheetNames(CLIENT_PATH, portfolioCliente)
substrings_to_check = ['carteira', 'política', 'politica']
nameClient = [name for name in nameClient if any(substring in name.lower() for substring in substrings_to_check)]
clientCarteira, clientPolitica = nameClient[0], nameClient[1]

# Base de Dados dos Fundos
nameResult = getSheetNames(PATH, databaseFundos)
resultBenchmark = nameResult[0]

# Árvore Classificação Insper
nameClass = getSheetNames(PATH, historicoBenchmarks)
classBenchmarks, classRetornos = nameClass[0], nameClass[1]

# %% [markdown]
# Leitura dos Excels da Empresa

# %%
# Carteira do Cliente:
carteira = pd.read_excel(f'{CLIENT_PATH}/{portfolioCliente}', sheet_name=clientCarteira, header=None)
politica = pd.read_excel(f'{CLIENT_PATH}/{portfolioCliente}', sheet_name=clientPolitica, header=None)

# Base de Dados Fundos
database = pd.read_excel(f'{PATH}/{databaseFundos}', sheet_name=resultBenchmark, header=None)

# Árvore Classificação Insper
benchmarks = pd.read_excel(f'{PATH}/{historicoBenchmarks}', sheet_name=classBenchmarks, header=None)
retornosBenchmarks = pd.read_excel(f'{PATH}/{historicoBenchmarks}', sheet_name=classRetornos, header=None)

# %% [markdown]
# ## Extração de Tabelas e Atribuição de Variáveis Dataframe

# %% [markdown]
# #### Extração de Tabelas dentro de cada Excel:

# %%
# Função para Ler as Tabelas dentro de cada Planilha
def getTables(df):
    # Transformando Dataframe em 0s e 1s
    larr = label(np.array(df.notnull()).astype("int"))
    
    tables = []
    for s in regionprops(larr):
        # Filtro de "Tabelas" Pequenas
        ux, lx, uy, ly = s.bbox
        diff_u, diff_l = uy - ux, ly - lx
        if diff_u <= 1 or diff_l <= 1:
            continue
        
        # Criação do Sub-Dataframe 
        table = df.iloc[
            s.bbox[0]:s.bbox[2], s.bbox[1]:s.bbox[3]
        ].pipe(
            lambda df_: df_.rename(columns=df_.iloc[0]).drop(df_.index[0])
        )

        # Adicionando Sub-Dataframe a Lista de Tables
        tables.append(table)
        
    return tables

# %%
dfsCarteira = getTables(carteira)
dfsPolitica = getTables(politica)
dfsDatabase = getTables(database)
dfsBenchmarks = getTables(benchmarks)
dfsRetornos = getTables(retornosBenchmarks)

# %% [markdown]
# #### Criando Variáveis para cada Tabela dos Excels

# %%
def attrDataframes(list_dfs):
    def getVarName(df):
        def namestr(obj, namespace):
            return [name for name in namespace if namespace[name] is obj]
    
        return namestr(df, globals())[0]
    
    for i in range(len(list_dfs)):
        dfName = getVarName(list_dfs).replace('dfs', '')
        
        varName = f'df{dfName}{i+1}'
        value = list_dfs[i]
        globals()[varName] = value
        
        print(f'- Dataframe {varName} created.')
    print('')

# %%
attrDataframes(dfsCarteira)
attrDataframes(dfsPolitica)
attrDataframes(dfsDatabase)
attrDataframes(dfsBenchmarks)
attrDataframes(dfsRetornos)
# Out:
# - Dataframe dfCarteira1 created.
#
# - Dataframe dfPolitica1 created.
# - Dataframe dfPolitica2 created.
# - Dataframe dfPolitica3 created.
#
# - Dataframe dfDatabase1 created.
#
# - Dataframe dfBenchmarks1 created.
#
# - Dataframe dfRetornos1 created.

# %% [markdown]
# ## Dataframes

# %% [markdown]
# ### - Carteira do Cliente:

# %%
valorCarteira = dfCarteira1["Financeiro"].iloc[-1]
perctCarteira = dfCarteira1["%"].iloc[-1]

# %%
tradingDesk = 'Carteira'
carteira = 'Financeiro'

dfCarteira1 = dfCarteira1.dropna(subset=[tradingDesk])
dfCarteira1 = dfCarteira1.dropna(subset=[carteira])

# %%
dfCarteira1.head()
# Out:
#           Data Posição      Source  \
# 4                  NaN         NaN
# 5  2023-09-13 00:00:00  KING - BRL
# 6  2023-09-13 00:00:00  KING - BRL
# 7  2023-09-13 00:00:00  KING - BRL
# 8  2023-09-13 00:00:00  KING - BRL
#
#                                           Carteira     Quantidade  \
# 4                     Renda Fixa Brasil Pós Fixado            NaN
# 5                             BV CASH FIRF SIMPLES   21170.299483
# 6  BTG PACTUAL DIGITAL TESOURO SELIC SIMPLES FI RF  218395.712765
# 7          LCI 30Jun2023 - 20Jun2025 96.5 BRADESCO         800000
# 8          LCA 30Aug2023 - 19Aug2025 94.5 BRADESCO        1000000
#
#        Financeiro                        Classe         %
# 4  2871779.418973                           NaN  0.233557
# 5    26943.031989  Renda Fixa Brasil Pós Fixado  0.002191
# 6    315562.17117  Renda Fixa Brasil Pós Fixado  0.025664
# 7   820257.249879  Renda Fixa Brasil Pós Fixado   0.06671
# 8  1004178.335827  Renda Fixa Brasil Pós Fixado  0.081668

# %% [markdown]
# ### - Política de Investimento

# %%
dfPolitica1.head()
# Out:
#   TradingDesk                                      Book Mínimo Máximo  \
# 1  KING - BRL                     Renda Fixa Brasil CDI   0.05   0.35
# 2  KING - BRL      Renda Fixa Brasil Crédito Pós-Fixado      0    0.2
# 3  KING - BRL              Renda Fixa Brasil Pré-Fixado      0    0.1
# 4  KING - BRL                Renda Fixa Brasil Inflação      0   0.15
# 5  KING - BRL  Renda Fixa Internacional Cash Equivalent      0   0.05
#
#   Estratégico Tático     Atual
# 1       0.075   0.13  0.233557
# 2        0.09   0.09  0.100853
# 3        0.04      0         0
# 4        0.08   0.12  0.109807
# 5           0  0.005  0.004163

# %%
dfPolitica2.rename(columns={'%':'Estratégico'}, inplace=True)
dfPolitica2.head()
# Out:
#    Alocação Estratégica por Mercado Estratégico
# 23                       Renda Fixa       0.315
# 24                 Retorno Absoluto        0.15
# 25                   Renda Variável       0.225
# 26                   Private Equity       0.255
# 27                      Real Estate       0.055

# %% [markdown]
# ### - Base de Dados Fundos: (retirar?)

# %%
dfDatabase1.head()
# Out:
#           ClassName         ClassLevelTwoName  \
# 1  Retorno Absoluto   Retorno Absoluto Brasil
# 2    Renda Variável  Renda Variável Doméstico
# 3        Renda Fixa     Renda Fixa Brasil CDI
# 4  Retorno Absoluto   Retorno Absoluto Brasil
# 5  Retorno Absoluto   Retorno Absoluto Brasil
#
#                     ClassLevelThreeName  \
# 1         Retorno Absoluto Brasil Macro
# 2        Renda Variável Doméstico Ações
# 3                    RF BR CDI Soberano
# 4         Retorno Absoluto Brasil Macro
# 5  Retorno Absoluto Brasil Equity Hedge
#
#                                      Name InvestmentTypeName  \
# 1                Ibiuna Hedge STH FIC FIM     InvestmentFund
# 2                 Bogari Value JC FIC FIA     InvestmentFund
# 3  BTG Pactual Tesouro Selic FI RF REF DI     InvestmentFund
# 4                   Kapitalo Zeta FIQ FIM     InvestmentFund
# 5       Moat Capital Equity Hedge FIC FIM     InvestmentFund
#
#   RedemptionQuotationDelayDayCountName RedemptionQuotationDelayDayCountValue  \
# 1                        Dias Corridos                                    30
# 2                        Dias Corridos                                    30
# 3                        Dias Corridos                                     0
# 4                           Dias Úteis                                    60
# 5                           Dias Úteis                                     0
#
#                         ExternalCode ExternalCodeSource
# 1           IBIUNA HEDGE STH FIC FIM            Lote 45
# 2             BOGARI VALE JC FIC FIM            Lote 45
# 3                TESOURO SELIC FI RF            Lote 45
# 4                  KAPITALO FIQ ZETA            Lote 45
# 5  MOAT CAPITAL EQUITY HEDGE FIC FIM            Lote 45

# %% [markdown]
# ### - Base de Dados e Histórico Benchmark:

# %%
dfBenchmarks1.head()
# Out:
#                                     Classes                     Benchmark  \
# 1                     Renda Fixa Brasil CDI                           CDI
# 2      Renda Fixa Brasil Crédito Pós-Fixado                        IDA-DI
# 3              Renda Fixa Brasil Pré-Fixado                      IRF-M 1+
# 4                Renda Fixa Brasil Inflação                         IMA-B
# 5  Renda Fixa Internacional Cash Equivalent  ICE U.S. Treasury Short Bond
#
#   Ticker Bloomberg
# 1   BZACCETP Index
# 2     IDADDI Index
# 3   BZRFIR1+ Index
# 4   BZRFIMAB INDEX
# 5   IDCOTSTR Index

# %%
dfRetornos1.head()
# Out:
#                   Data Renda Fixa Brasil CDI  \
# 1  2012-01-31 00:00:00              0.008874
# 2  2012-02-29 00:00:00              0.007417
# 3  2012-03-30 00:00:00               0.00811
# 4  2012-04-30 00:00:00              0.007029
# 5  2012-05-31 00:00:00              0.007339
#
#   Renda Fixa Brasil Crédito Pós-Fixado Renda Fixa Brasil Pré-Fixado  \
# 1                             0.009366                     0.014172
# 2                             0.008443                     0.012284
# 3                             0.009322                     0.012667
# 4                              0.00821                     0.022992
# 5                             0.008355                     0.019004
#
#   Renda Fixa Brasil Inflação Renda Fixa Internacional Cash Equivalent  \
# 1                   0.016315                                 0.000059
# 2                   0.021733                                -0.000063
# 3                   0.019131                                 0.000087
# 4                   0.044201                                 0.000153
# 5                    0.01966                                  0.00019
#
#   Renda Fixa Internacional Pré-Fixado Renda Fixa Internacional Inflação  \
# 1                            0.009881                          0.023482
# 2                            0.003615                         -0.003757
# 3                           -0.001447                         -0.011348
# 4                            0.006232                          0.021172
# 5                             0.01041                          0.018462
#
#   Renda Fixa Internacional Crédito Retorno Absoluto Brasil  \
# 1                         0.035732                0.016157
# 2                         0.030352                0.015766
# 3                          0.00147                0.012393
# 4                         0.008794                0.018731
# 5                         -0.02004                0.008606
#
#   Retorno Absoluto Internacional Renda Variável Brasil  \
# 1                       0.027792              0.111326
# 2                       0.020579              0.043433
# 3                      -0.001776             -0.019765
# 4                      -0.005121             -0.041709
# 5                      -0.026106             -0.118567
#
#   Renda Variável Internacional Private Equity Brasil  \
# 1                     0.050183               0.08251
# 2                     0.048849              0.094339
# 3                     0.012856              0.018434
# 4                    -0.011356             -0.002949
# 5                    -0.086324             -0.110974
#
#   Private Equity Internacional Real Estate Brasil Real Estate Internacional  \
# 1                            0           0.030333                  0.083108
# 2                            0           0.046483                  0.039845
# 3                       0.0633           0.040653                   0.00741
# 4                            0           0.014343                  0.021775
# 5                            0           0.034245                 -0.067054
#
#   Commodities
# 1    0.022312
# 2    0.060629
# 3   -0.023503
# 4   -0.005123
# 5   -0.129788

# %% [markdown]
# ## Rebalanceamento do Portfólio:

# %% [markdown]
# ### Dataframes Importantes para Análise

# %% [markdown]
# Dataframe para checar o Rebalanceamento

# %%
book = 'Book'
min = 'Mínimo'
max = 'Máximo'
tat = 'Tático'
atual = 'Atual'

dfRebalance = dfPolitica1[[book, min, max, tat, atual]]
dfRebalance.insert(4, 'Offset', dfRebalance['Atual'] - dfRebalance['Tático'])
dfRebalance.set_index('Book', inplace=True)
dfRebalance
# Out:
#                                          Mínimo Máximo Tático    Offset  \
# Book
# Renda Fixa Brasil CDI                      0.05   0.35   0.13  0.103557
# Renda Fixa Brasil Crédito Pós-Fixado          0    0.2   0.09  0.010853
# Renda Fixa Brasil Pré-Fixado                  0    0.1      0         0
# Renda Fixa Brasil Inflação                    0   0.15   0.12 -0.010193
# Renda Fixa Internacional Cash Equivalent      0   0.05  0.005 -0.000837
# Renda Fixa Internacional Pré-Fixado           0   0.05   0.01 -0.001674
# Renda Fixa Internacional Inflação             0   0.05  0.005 -0.002919
# Renda Fixa Internacional Crédito              0    0.1   0.03 -0.013972
# Retorno Absoluto Brasil                       0    0.2    0.1 -0.012327
# Retorno Absoluto Internacional                0    0.1   0.01 -0.001674
# Renda Variável Brasil                       0.1    0.3   0.15  0.013536
# Renda Variável Internacional               0.05   0.15   0.05  0.001166
# Private Equity Brasil                         0    0.1   0.03   0.04775
# Private Equity Internacional              0.175    0.3  0.225 -0.136014
# Real Estate Brasil                            0   0.05   0.01   0.01579
# Real Estate Internacional                     0    0.1   0.03 -0.010121
# Commodities                                   0   0.05  0.005 -0.002919
#
#                                              Atual
# Book
# Renda Fixa Brasil CDI                     0.233557
# Renda Fixa Brasil Crédito Pós-Fixado      0.100853
# Renda Fixa Brasil Pré-Fixado                     0
# Renda Fixa Brasil Inflação                0.109807
# Renda Fixa Internacional Cash Equivalent  0.004163
# Renda Fixa Internacional Pré-Fixado       0.008326
# Renda Fixa Internacional Inflação         0.002081
# Renda Fixa Internacional Crédito          0.016028
# Retorno Absoluto Brasil                   0.087673
# Retorno Absoluto Internacional            0.008326
# Renda Variável Brasil                     0.163536
# Renda Variável Internacional              0.051166
# Private Equity Brasil                      0.07775
# Private Equity Internacional              0.088986
# Real Estate Brasil                         0.02579
# Real Estate Internacional                 0.019879
# Commodities                               0.002081

# %% [markdown]
# Dataframe de Análise do Portfólio

# %%
resultPortfolio = dfPolitica1[['Book', 'Tático', 'Atual']]
resultPortfolio['Offset'] = resultPortfolio['Atual'] - resultPortfolio['Tático']

resultPortfolio = resultPortfolio[['Book', 'Tático', 'Atual', 'Offset']]
resultPortfolio.set_index('Book', inplace=True)

resultPortfolio
# Out:
#                                          Tático     Atual    Offset
# Book
# Renda Fixa Brasil CDI                      0.13  0.233557  0.103557
# Renda Fixa Brasil Crédito Pós-Fixado       0.09  0.100853  0.010853
# Renda Fixa Brasil Pré-Fixado                  0         0         0
# Renda Fixa Brasil Inflação                 0.12  0.109807 -0.010193
# Renda Fixa Internacional Cash Equivalent  0.005  0.004163 -0.000837
# Renda Fixa Internacional Pré-Fixado        0.01  0.008326 -0.001674
# Renda Fixa Internacional Inflação         0.005  0.002081 -0.002919
# Renda Fixa Internacional Crédito           0.03  0.016028 -0.013972
# Retorno Absoluto Brasil                     0.1  0.087673 -0.012327
# Retorno Absoluto Internacional             0.01  0.008326 -0.001674
# Renda Variável Brasil                      0.15  0.163536  0.013536
# Renda Variável Internacional               0.05  0.051166  0.001166
# Private Equity Brasil                      0.03   0.07775   0.04775
# Private Equity Internacional              0.225  0.088986 -0.136014
# Real Estate Brasil                         0.01   0.02579   0.01579
# Real Estate Internacional                  0.03  0.019879 -0.010121
# Commodities                               0.005  0.002081 -0.002919

# %% [markdown]
# ### TE - Tracking Error do Portfólio:

# %%
retTatico = dfRetornos1.copy()
retTatico.set_index('Data', inplace=True)

for index, row in resultPortfolio.iterrows():
    book = index
    currentPerc = row['Tático']

    retTatico[book] = retTatico[book] * currentPerc

retTatico['Retorno Tático'] = retTatico.sum(axis=1)

# retTatico.head()

# %%
retAtual = dfRetornos1.copy()
retAtual.set_index('Data', inplace=True)

for index, row in resultPortfolio.iterrows():
    book = index
    currentPerc = row['Atual']

    retAtual[book] = retAtual[book] * currentPerc

retAtual['Retorno Atual'] = retAtual.sum(axis=1)
    
# retAtual.head()

# %%
trackingError = pd.DataFrame({
    'Retorno Atual': retAtual['Retorno Atual'],
    'Retorno Tático': retTatico['Retorno Tático']
})

trackingError['Excesso'] = trackingError['Retorno Atual'] - trackingError['Retorno Tático']

trackingError.head()
# Out:
#             Retorno Atual  Retorno Tático   Excesso
# Data
# 2012-01-31       0.036830        0.031728  0.005102
# 2012-02-29       0.026087        0.020793  0.005294
# 2012-03-30       0.011634        0.018369 -0.006735
# 2012-04-30       0.002321        0.003070 -0.000749
# 2012-05-31      -0.028098       -0.023488 -0.004610

# %%
te = trackingError['Excesso'].std()
te = te * math.sqrt(12)

print(f"Tracking Error do Portfólio: {te:.4%}")

def send_notification(title, message):
    notification.notify(
        title=title,
        message=message,
        timeout=10  # Notification will disappear after 10 seconds
    )

if te*100 > perfilRisco:
    surplus = te-perfilRisco/100
    send_notification('Alerta!', f'Você está {surplus:.3%} acima do Perfil de Risco')
else:
    send_notification('Tudo Certo!', f'O Tracking Error está abaixo de {perfilRisco}%')
# Out:
# Tracking Error do Portfólio: 1.6686%

# %% [markdown]
# ### CTR - Contribution To Risk:

# %%
tradingDeskList = dfPolitica1['Book'].to_list()

def listFilterWords(columnList):
    columnList = [item.replace('-', ' ') for item in columnList]
    return [unidecode(item).lower() for item in columnList]

tradingDeskList = listFilterWords(tradingDeskList)

# %%
matrizCov = dfRetornos1.copy()

def dfFilterWords(column_name):
    return unidecode(column_name).replace('-', ' ').lower()

matrizCov = matrizCov.rename(columns=dfFilterWords)
matrizCov.reset_index(drop=True)
matrizCov.drop('data', axis=1, inplace=True)
matrizCov = matrizCov.astype(float)
matrizCov = matrizCov[tradingDeskList]

# %%
mCov = matrizCov.cov()

mCov
# Out:
#                                           renda fixa brasil cdi  \
# renda fixa brasil cdi                              8.814434e-06
# renda fixa brasil credito pos fixado               8.619501e-06
# renda fixa brasil pre fixado                       1.062777e-05
# renda fixa brasil inflacao                         6.674533e-06
# renda fixa internacional cash equivalent           4.353958e-07
# renda fixa internacional pre fixado               -1.621794e-06
# renda fixa internacional inflacao                 -6.421802e-06
# renda fixa internacional credito                  -2.387879e-06
# retorno absoluto brasil                            5.799491e-06
# retorno absoluto internacional                    -8.759983e-06
# renda variavel brasil                             -2.120479e-06
# renda variavel internacional                      -1.473123e-05
# private equity brasil                             -1.006200e-05
# private equity internacional                      -1.851157e-05
# real estate brasil                                 1.034035e-05
# real estate internacional                         -1.109573e-05
# commodities                                       -2.667517e-05
#
#                                           renda fixa brasil credito pos fixado  \
# renda fixa brasil cdi                                             8.619501e-06
# renda fixa brasil credito pos fixado                              3.496188e-05
# renda fixa brasil pre fixado                                      1.343194e-05
# renda fixa brasil inflacao                                        3.744366e-05
# renda fixa internacional cash equivalent                         -1.716438e-06
# renda fixa internacional pre fixado                               1.335374e-06
# renda fixa internacional inflacao                                -6.401599e-07
# renda fixa internacional credito                                  5.422794e-05
# retorno absoluto brasil                                           3.510765e-05
# retorno absoluto internacional                                    3.357756e-05
# renda variavel brasil                                             1.346952e-04
# renda variavel internacional                                      4.333268e-05
# private equity brasil                                             1.511664e-04
# private equity internacional                                      2.873725e-05
# real estate brasil                                                8.019209e-05
# real estate internacional                                         7.484440e-05
# commodities                                                       1.139806e-04
#
#                                           renda fixa brasil pre fixado  \
# renda fixa brasil cdi                                         0.000011
# renda fixa brasil credito pos fixado                          0.000013
# renda fixa brasil pre fixado                                  0.000207
# renda fixa brasil inflacao                                    0.000242
# renda fixa internacional cash equivalent                      0.000002
# renda fixa internacional pre fixado                           0.000034
# renda fixa internacional inflacao                             0.000059
# renda fixa internacional credito                              0.000096
# retorno absoluto brasil                                       0.000068
# retorno absoluto internacional                                0.000021
# renda variavel brasil                                         0.000431
# renda variavel internacional                                  0.000064
# private equity brasil                                         0.000480
# private equity internacional                                  0.000023
# real estate brasil                                            0.000220
# real estate internacional                                     0.000116
# commodities                                                  -0.000007
#
#                                           renda fixa brasil inflacao  \
# renda fixa brasil cdi                                   6.674533e-06
# renda fixa brasil credito pos fixado                    3.744366e-05
# renda fixa brasil pre fixado                            2.418824e-04
# renda fixa brasil inflacao                              4.394471e-04
# renda fixa internacional cash equivalent               -3.761120e-07
# renda fixa internacional pre fixado                     5.108149e-05
# renda fixa internacional inflacao                       1.000431e-04
# renda fixa internacional credito                        1.974998e-04
# retorno absoluto brasil                                 1.307119e-04
# retorno absoluto internacional                          1.024653e-04
# renda variavel brasil                                   7.760132e-04
# renda variavel internacional                            2.081047e-04
# private equity brasil                                   8.502619e-04
# private equity internacional                            6.710910e-05
# real estate brasil                                      3.472580e-04
# real estate internacional                               3.588451e-04
# commodities                                             2.350159e-04
#
#                                           renda fixa internacional cash equivalent  \
# renda fixa brasil cdi                                                 4.353958e-07
# renda fixa brasil credito pos fixado                                 -1.716438e-06
# renda fixa brasil pre fixado                                          2.396870e-06
# renda fixa brasil inflacao                                           -3.761120e-07
# renda fixa internacional cash equivalent                              1.543532e-06
# renda fixa internacional pre fixado                                   1.228657e-06
# renda fixa internacional inflacao                                     1.005218e-06
# renda fixa internacional credito                                     -3.082405e-06
# retorno absoluto brasil                                              -4.478402e-06
# retorno absoluto internacional                                       -4.160415e-06
# renda variavel brasil                                                -6.907199e-06
# renda variavel internacional                                         -5.919274e-06
# private equity brasil                                                -8.384342e-06
# private equity internacional                                         -5.285704e-06
# real estate brasil                                                   -4.291754e-06
# real estate internacional                                            -9.693904e-06
# commodities                                                          -1.040034e-05
#
#                                           renda fixa internacional pre fixado  \
# renda fixa brasil cdi                                               -0.000002
# renda fixa brasil credito pos fixado                                 0.000001
# renda fixa brasil pre fixado                                         0.000034
# renda fixa brasil inflacao                                           0.000051
# renda fixa internacional cash equivalent                             0.000001
# renda fixa internacional pre fixado                                  0.000102
# renda fixa internacional inflacao                                    0.000129
# renda fixa internacional credito                                     0.000103
# retorno absoluto brasil                                              0.000001
# retorno absoluto internacional                                       0.000032
# renda variavel brasil                                                0.000088
# renda variavel internacional                                         0.000133
# private equity brasil                                                0.000115
# private equity internacional                                         0.000014
# real estate brasil                                                   0.000005
# real estate internacional                                            0.000227
# commodities                                                         -0.000106
#
#                                           renda fixa internacional inflacao  \
# renda fixa brasil cdi                                         -6.421802e-06
# renda fixa brasil credito pos fixado                          -6.401599e-07
# renda fixa brasil pre fixado                                   5.910725e-05
# renda fixa brasil inflacao                                     1.000431e-04
# renda fixa internacional cash equivalent                       1.005218e-06
# renda fixa internacional pre fixado                            1.292867e-04
# renda fixa internacional inflacao                              2.379075e-04
# renda fixa internacional credito                               1.667479e-04
# retorno absoluto brasil                                        2.698196e-06
# retorno absoluto internacional                                 7.779472e-05
# renda variavel brasil                                          2.228119e-04
# renda variavel internacional                                   2.538703e-04
# private equity brasil                                          2.327620e-04
# private equity internacional                                   2.493368e-05
# real estate brasil                                             5.150091e-05
# real estate internacional                                      3.965304e-04
# commodities                                                    3.140307e-05
#
#                                           renda fixa internacional credito  \
# renda fixa brasil cdi                                            -0.000002
# renda fixa brasil credito pos fixado                              0.000054
# renda fixa brasil pre fixado                                      0.000096
# renda fixa brasil inflacao                                        0.000197
# renda fixa internacional cash equivalent                         -0.000003
# renda fixa internacional pre fixado                               0.000103
# renda fixa internacional inflacao                                 0.000167
# renda fixa internacional credito                                  0.000464
# retorno absoluto brasil                                           0.000123
# retorno absoluto internacional                                    0.000297
# renda variavel brasil                                             0.000923
# renda variavel internacional                                      0.000724
# private equity brasil                                             0.001008
# private equity internacional                                      0.000140
# real estate brasil                                                0.000351
# real estate internacional                                         0.000762
# commodities                                                       0.000718
#
#                                           retorno absoluto brasil  \
# renda fixa brasil cdi                                    0.000006
# renda fixa brasil credito pos fixado                     0.000035
# renda fixa brasil pre fixado                             0.000068
# renda fixa brasil inflacao                               0.000131
# renda fixa internacional cash equivalent                -0.000004
# renda fixa internacional pre fixado                      0.000001
# renda fixa internacional inflacao                        0.000003
# renda fixa internacional credito                         0.000123
# retorno absoluto brasil                                  0.000151
# retorno absoluto internacional                           0.000102
# renda variavel brasil                                    0.000448
# renda variavel internacional                             0.000173
# private equity brasil                                    0.000545
# private equity internacional                             0.000054
# real estate brasil                                       0.000183
# real estate internacional                                0.000197
# commodities                                              0.000225
#
#                                           retorno absoluto internacional  \
# renda fixa brasil cdi                                          -0.000009
# renda fixa brasil credito pos fixado                            0.000034
# renda fixa brasil pre fixado                                    0.000021
# renda fixa brasil inflacao                                      0.000102
# renda fixa internacional cash equivalent                       -0.000004
# renda fixa internacional pre fixado                             0.000032
# renda fixa internacional inflacao                               0.000078
# renda fixa internacional credito                                0.000297
# retorno absoluto brasil                                         0.000102
# retorno absoluto internacional                                  0.000279
# renda variavel brasil                                           0.000649
# renda variavel internacional                                    0.000598
# private equity brasil                                           0.000719
# private equity internacional                                    0.000130
# real estate brasil                                              0.000238
# real estate internacional                                       0.000573
# commodities                                                     0.000621
#
#                                           renda variavel brasil  \
# renda fixa brasil cdi                                 -0.000002
# renda fixa brasil credito pos fixado                   0.000135
# renda fixa brasil pre fixado                           0.000431
# renda fixa brasil inflacao                             0.000776
# renda fixa internacional cash equivalent              -0.000007
# renda fixa internacional pre fixado                    0.000088
# renda fixa internacional inflacao                      0.000223
# renda fixa internacional credito                       0.000923
# retorno absoluto brasil                                0.000448
# retorno absoluto internacional                         0.000649
# renda variavel brasil                                  0.004069
# renda variavel internacional                           0.001459
# private equity brasil                                  0.003960
# private equity internacional                           0.000407
# real estate brasil                                     0.001217
# real estate internacional                              0.001536
# commodities                                            0.001791
#
#                                           renda variavel internacional  \
# renda fixa brasil cdi                                        -0.000015
# renda fixa brasil credito pos fixado                          0.000043
# renda fixa brasil pre fixado                                  0.000064
# renda fixa brasil inflacao                                    0.000208
# renda fixa internacional cash equivalent                     -0.000006
# renda fixa internacional pre fixado                           0.000133
# renda fixa internacional inflacao                             0.000254
# renda fixa internacional credito                              0.000724
# retorno absoluto brasil                                       0.000173
# retorno absoluto internacional                                0.000598
# renda variavel brasil                                         0.001459
# renda variavel internacional                                  0.001694
# private equity brasil                                         0.001555
# private equity internacional                                  0.000207
# real estate brasil                                            0.000460
# real estate internacional                                     0.001519
# commodities                                                   0.001234
#
#                                           private equity brasil  \
# renda fixa brasil cdi                                 -0.000010
# renda fixa brasil credito pos fixado                   0.000151
# renda fixa brasil pre fixado                           0.000480
# renda fixa brasil inflacao                             0.000850
# renda fixa internacional cash equivalent              -0.000008
# renda fixa internacional pre fixado                    0.000115
# renda fixa internacional inflacao                      0.000233
# renda fixa internacional credito                       0.001008
# retorno absoluto brasil                                0.000545
# retorno absoluto internacional                         0.000719
# renda variavel brasil                                  0.003960
# renda variavel internacional                           0.001555
# private equity brasil                                  0.004828
# private equity internacional                           0.000516
# real estate brasil                                     0.001470
# real estate internacional                              0.001667
# commodities                                            0.001723
#
#                                           private equity internacional  \
# renda fixa brasil cdi                                        -0.000019
# renda fixa brasil credito pos fixado                          0.000029
# renda fixa brasil pre fixado                                  0.000023
# renda fixa brasil inflacao                                    0.000067
# renda fixa internacional cash equivalent                     -0.000005
# renda fixa internacional pre fixado                           0.000014
# renda fixa internacional inflacao                             0.000025
# renda fixa internacional credito                              0.000140
# retorno absoluto brasil                                       0.000054
# retorno absoluto internacional                                0.000130
# renda variavel brasil                                         0.000407
# renda variavel internacional                                  0.000207
# private equity brasil                                         0.000516
# private equity internacional                                  0.000839
# real estate brasil                                            0.000204
# real estate internacional                                     0.000260
# commodities                                                   0.000416
#
#                                           real estate brasil  \
# renda fixa brasil cdi                               0.000010
# renda fixa brasil credito pos fixado                0.000080
# renda fixa brasil pre fixado                        0.000220
# renda fixa brasil inflacao                          0.000347
# renda fixa internacional cash equivalent           -0.000004
# renda fixa internacional pre fixado                 0.000005
# renda fixa internacional inflacao                   0.000052
# renda fixa internacional credito                    0.000351
# retorno absoluto brasil                             0.000183
# retorno absoluto internacional                      0.000238
# renda variavel brasil                               0.001217
# renda variavel internacional                        0.000460
# private equity brasil                               0.001470
# private equity internacional                        0.000204
# real estate brasil                                  0.001056
# real estate internacional                           0.000558
# commodities                                         0.000684
#
#                                           real estate internacional  \
# renda fixa brasil cdi                                     -0.000011
# renda fixa brasil credito pos fixado                       0.000075
# renda fixa brasil pre fixado                               0.000116
# renda fixa brasil inflacao                                 0.000359
# renda fixa internacional cash equivalent                  -0.000010
# renda fixa internacional pre fixado                        0.000227
# renda fixa internacional inflacao                          0.000397
# renda fixa internacional credito                           0.000762
# retorno absoluto brasil                                    0.000197
# retorno absoluto internacional                             0.000573
# renda variavel brasil                                      0.001536
# renda variavel internacional                               0.001519
# private equity brasil                                      0.001667
# private equity internacional                               0.000260
# real estate brasil                                         0.000558
# real estate internacional                                  0.002019
# commodities                                                0.001078
#
#                                           commodities
# renda fixa brasil cdi                       -0.000027
# renda fixa brasil credito pos fixado         0.000114
# renda fixa brasil pre fixado                -0.000007
# renda fixa brasil inflacao                   0.000235
# renda fixa internacional cash equivalent    -0.000010
# renda fixa internacional pre fixado         -0.000106
# renda fixa internacional inflacao            0.000031
# renda fixa internacional credito             0.000718
# retorno absoluto brasil                      0.000225
# retorno absoluto internacional               0.000621
# renda variavel brasil                        0.001791
# renda variavel internacional                 0.001234
# private equity brasil                        0.001723
# private equity internacional                 0.000416
# real estate brasil                           0.000684
# real estate internacional                    0.001078
# commodities                                  0.003866

# %%
pWeights = resultPortfolio["Atual"].to_list()

pVariance = np.dot(pWeights, np.dot(mCov, pWeights))
pVolatility = math.sqrt(pVariance)

print(f"Variância do Portfólio: {pVariance:.5e}")
print(f"Volatilidade do Portfólio: {pVolatility:.5%}")
# Out:
# Variância do Portfólio: 4.58810e-04
# Volatilidade do Portfólio: 2.14198%

# %%
covPonderada = np.dot(pWeights, mCov)

# covPonderada

# %%
riskContribuition = []

for i in range(len(covPonderada)):
    riskContribuition.append(pWeights[i] * covPonderada[i]/pVariance)

riskContribuition = list(i * 100 for i in riskContribuition)

CTR = pd.DataFrame({
    'Ativos': resultPortfolio.index.to_list(),
    'Contribuição [%]': riskContribuition
})

CTR = CTR.sort_values(by='Contribuição [%]', ascending=False)

def highlight_row(s):
    return ['background-color: yellow' if i < nAplicacoes else '' for i in range(len(s))]

highlightedCTR = CTR.style.apply(highlight_row)

highlightedCTR
# Out:
# <style type="text/css">
# #T_ab6e3_row0_col0, #T_ab6e3_row0_col1, #T_ab6e3_row1_col0, #T_ab6e3_row1_col1, #T_ab6e3_row2_col0, #T_ab6e3_row2_col1, #T_ab6e3_row3_col0, #T_ab6e3_row3_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_ab6e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab6e3_level0_col0" class="col_heading level0 col0" >Ativos</th>
#       <th id="T_ab6e3_level0_col1" class="col_heading level0 col1" >Contribuição [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab6e3_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_ab6e3_row0_col0" class="data row0 col0" >Renda Variável Brasil</td>
#       <td id="T_ab6e3_row0_col1" class="data row0 col1" >46.652426</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_ab6e3_row1_col0" class="data row1 col0" >Private Equity Brasil</td>
#       <td id="T_ab6e3_row1_col1" class="data row1 col1" >23.737697</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ab6e3_row2_col0" class="data row2 col0" >Renda Fixa Brasil Inflação</td>
#       <td id="T_ab6e3_row2_col1" class="data row2 col1" >7.082032</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_ab6e3_row3_col0" class="data row3 col0" >Renda Variável Internacional</td>
#       <td id="T_ab6e3_row3_col1" class="data row3 col1" >6.316326</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row4" class="row_heading level0 row4" >13</th>
#       <td id="T_ab6e3_row4_col0" class="data row4 col0" >Private Equity Internacional</td>
#       <td id="T_ab6e3_row4_col1" class="data row4 col1" >4.217852</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_ab6e3_row5_col0" class="data row5 col0" >Retorno Absoluto Brasil</td>
#       <td id="T_ab6e3_row5_col1" class="data row5 col1" >3.320610</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_ab6e3_row6_col0" class="data row6 col0" >Real Estate Internacional</td>
#       <td id="T_ab6e3_row6_col1" class="data row6 col1" >2.684843</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row7" class="row_heading level0 row7" >14</th>
#       <td id="T_ab6e3_row7_col0" class="data row7 col0" >Real Estate Brasil</td>
#       <td id="T_ab6e3_row7_col1" class="data row7 col1" >2.625618</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_ab6e3_row8_col0" class="data row8 col0" >Renda Fixa Brasil Crédito Pós-Fixado</td>
#       <td id="T_ab6e3_row8_col1" class="data row8 col1" >1.235980</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_ab6e3_row9_col0" class="data row9 col0" >Renda Fixa Internacional Crédito</td>
#       <td id="T_ab6e3_row9_col1" class="data row9 col1" >1.233460</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_ab6e3_row10_col0" class="data row10 col0" >Retorno Absoluto Internacional</td>
#       <td id="T_ab6e3_row10_col1" class="data row10 col1" >0.457599</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row11" class="row_heading level0 row11" >16</th>
#       <td id="T_ab6e3_row11_col0" class="data row11 col0" >Commodities</td>
#       <td id="T_ab6e3_row11_col1" class="data row11 col1" >0.290677</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row12" class="row_heading level0 row12" >5</th>
#       <td id="T_ab6e3_row12_col0" class="data row12 col0" >Renda Fixa Internacional Pré-Fixado</td>
#       <td id="T_ab6e3_row12_col1" class="data row12 col1" >0.080436</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row13" class="row_heading level0 row13" >6</th>
#       <td id="T_ab6e3_row13_col0" class="data row13 col0" >Renda Fixa Internacional Inflação</td>
#       <td id="T_ab6e3_row13_col1" class="data row13 col1" >0.042449</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row14" class="row_heading level0 row14" >0</th>
#       <td id="T_ab6e3_row14_col0" class="data row14 col0" >Renda Fixa Brasil CDI</td>
#       <td id="T_ab6e3_row14_col1" class="data row14 col1" >0.025125</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row15" class="row_heading level0 row15" >2</th>
#       <td id="T_ab6e3_row15_col0" class="data row15 col0" >Renda Fixa Brasil Pré-Fixado</td>
#       <td id="T_ab6e3_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ab6e3_level0_row16" class="row_heading level0 row16" >4</th>
#       <td id="T_ab6e3_row16_col0" class="data row16 col0" >Renda Fixa Internacional Cash Equivalent</td>
#       <td id="T_ab6e3_row16_col1" class="data row16 col1" >-0.003131</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Offset:

# %%
dfOffset = resultPortfolio.copy()

dfOffset = dfOffset.iloc[dfOffset['Offset'].abs().argsort()[::-1]]

def highlight_row(s):
    return ['background-color: yellow' if i < nAplicacoes else '' for i in range(len(s))]

highlightedOffset = dfOffset.style.apply(highlight_row)

highlightedOffset
# Out:
# <style type="text/css">
# #T_64fb7_row0_col0, #T_64fb7_row0_col1, #T_64fb7_row0_col2, #T_64fb7_row1_col0, #T_64fb7_row1_col1, #T_64fb7_row1_col2, #T_64fb7_row2_col0, #T_64fb7_row2_col1, #T_64fb7_row2_col2, #T_64fb7_row3_col0, #T_64fb7_row3_col1, #T_64fb7_row3_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_64fb7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64fb7_level0_col0" class="col_heading level0 col0" >Tático</th>
#       <th id="T_64fb7_level0_col1" class="col_heading level0 col1" >Atual</th>
#       <th id="T_64fb7_level0_col2" class="col_heading level0 col2" >Offset</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Book</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64fb7_level0_row0" class="row_heading level0 row0" >Private Equity Internacional</th>
#       <td id="T_64fb7_row0_col0" class="data row0 col0" >0.225000</td>
#       <td id="T_64fb7_row0_col1" class="data row0 col1" >0.088986</td>
#       <td id="T_64fb7_row0_col2" class="data row0 col2" >-0.136014</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row1" class="row_heading level0 row1" >Renda Fixa Brasil CDI</th>
#       <td id="T_64fb7_row1_col0" class="data row1 col0" >0.130000</td>
#       <td id="T_64fb7_row1_col1" class="data row1 col1" >0.233557</td>
#       <td id="T_64fb7_row1_col2" class="data row1 col2" >0.103557</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row2" class="row_heading level0 row2" >Private Equity Brasil</th>
#       <td id="T_64fb7_row2_col0" class="data row2 col0" >0.030000</td>
#       <td id="T_64fb7_row2_col1" class="data row2 col1" >0.077750</td>
#       <td id="T_64fb7_row2_col2" class="data row2 col2" >0.047750</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row3" class="row_heading level0 row3" >Real Estate Brasil</th>
#       <td id="T_64fb7_row3_col0" class="data row3 col0" >0.010000</td>
#       <td id="T_64fb7_row3_col1" class="data row3 col1" >0.025790</td>
#       <td id="T_64fb7_row3_col2" class="data row3 col2" >0.015790</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row4" class="row_heading level0 row4" >Renda Fixa Internacional Crédito</th>
#       <td id="T_64fb7_row4_col0" class="data row4 col0" >0.030000</td>
#       <td id="T_64fb7_row4_col1" class="data row4 col1" >0.016028</td>
#       <td id="T_64fb7_row4_col2" class="data row4 col2" >-0.013972</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row5" class="row_heading level0 row5" >Renda Variável Brasil</th>
#       <td id="T_64fb7_row5_col0" class="data row5 col0" >0.150000</td>
#       <td id="T_64fb7_row5_col1" class="data row5 col1" >0.163536</td>
#       <td id="T_64fb7_row5_col2" class="data row5 col2" >0.013536</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row6" class="row_heading level0 row6" >Retorno Absoluto Brasil</th>
#       <td id="T_64fb7_row6_col0" class="data row6 col0" >0.100000</td>
#       <td id="T_64fb7_row6_col1" class="data row6 col1" >0.087673</td>
#       <td id="T_64fb7_row6_col2" class="data row6 col2" >-0.012327</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row7" class="row_heading level0 row7" >Renda Fixa Brasil Crédito Pós-Fixado</th>
#       <td id="T_64fb7_row7_col0" class="data row7 col0" >0.090000</td>
#       <td id="T_64fb7_row7_col1" class="data row7 col1" >0.100853</td>
#       <td id="T_64fb7_row7_col2" class="data row7 col2" >0.010853</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row8" class="row_heading level0 row8" >Renda Fixa Brasil Inflação</th>
#       <td id="T_64fb7_row8_col0" class="data row8 col0" >0.120000</td>
#       <td id="T_64fb7_row8_col1" class="data row8 col1" >0.109807</td>
#       <td id="T_64fb7_row8_col2" class="data row8 col2" >-0.010193</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row9" class="row_heading level0 row9" >Real Estate Internacional</th>
#       <td id="T_64fb7_row9_col0" class="data row9 col0" >0.030000</td>
#       <td id="T_64fb7_row9_col1" class="data row9 col1" >0.019879</td>
#       <td id="T_64fb7_row9_col2" class="data row9 col2" >-0.010121</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row10" class="row_heading level0 row10" >Renda Fixa Internacional Inflação</th>
#       <td id="T_64fb7_row10_col0" class="data row10 col0" >0.005000</td>
#       <td id="T_64fb7_row10_col1" class="data row10 col1" >0.002081</td>
#       <td id="T_64fb7_row10_col2" class="data row10 col2" >-0.002919</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row11" class="row_heading level0 row11" >Commodities</th>
#       <td id="T_64fb7_row11_col0" class="data row11 col0" >0.005000</td>
#       <td id="T_64fb7_row11_col1" class="data row11 col1" >0.002081</td>
#       <td id="T_64fb7_row11_col2" class="data row11 col2" >-0.002919</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row12" class="row_heading level0 row12" >Retorno Absoluto Internacional</th>
#       <td id="T_64fb7_row12_col0" class="data row12 col0" >0.010000</td>
#       <td id="T_64fb7_row12_col1" class="data row12 col1" >0.008326</td>
#       <td id="T_64fb7_row12_col2" class="data row12 col2" >-0.001674</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row13" class="row_heading level0 row13" >Renda Fixa Internacional Pré-Fixado</th>
#       <td id="T_64fb7_row13_col0" class="data row13 col0" >0.010000</td>
#       <td id="T_64fb7_row13_col1" class="data row13 col1" >0.008326</td>
#       <td id="T_64fb7_row13_col2" class="data row13 col2" >-0.001674</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row14" class="row_heading level0 row14" >Renda Variável Internacional</th>
#       <td id="T_64fb7_row14_col0" class="data row14 col0" >0.050000</td>
#       <td id="T_64fb7_row14_col1" class="data row14 col1" >0.051166</td>
#       <td id="T_64fb7_row14_col2" class="data row14 col2" >0.001166</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row15" class="row_heading level0 row15" >Renda Fixa Internacional Cash Equivalent</th>
#       <td id="T_64fb7_row15_col0" class="data row15 col0" >0.005000</td>
#       <td id="T_64fb7_row15_col1" class="data row15 col1" >0.004163</td>
#       <td id="T_64fb7_row15_col2" class="data row15 col2" >-0.000837</td>
#     </tr>
#     <tr>
#       <th id="T_64fb7_level0_row16" class="row_heading level0 row16" >Renda Fixa Brasil Pré-Fixado</th>
#       <td id="T_64fb7_row16_col0" class="data row16 col0" >0</td>
#       <td id="T_64fb7_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_64fb7_row16_col2" class="data row16 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Otimização:

# %% [markdown]
# #### Otimização Setup

# %% [markdown]
# Preparando o Dataframe de Otimização:

# %%
dfOtimizado = dfRebalance.copy()

dfOtimizado['Otimizado CTR'] = dfOtimizado['Atual']
dfOtimizado['Otimizado Offset'] = dfOtimizado['Atual']

dfOtimizado
# Out:
#                                          Mínimo Máximo Tático    Offset  \
# Book
# Renda Fixa Brasil CDI                      0.05   0.35   0.13  0.103557
# Renda Fixa Brasil Crédito Pós-Fixado          0    0.2   0.09  0.010853
# Renda Fixa Brasil Pré-Fixado                  0    0.1      0         0
# Renda Fixa Brasil Inflação                    0   0.15   0.12 -0.010193
# Renda Fixa Internacional Cash Equivalent      0   0.05  0.005 -0.000837
# Renda Fixa Internacional Pré-Fixado           0   0.05   0.01 -0.001674
# Renda Fixa Internacional Inflação             0   0.05  0.005 -0.002919
# Renda Fixa Internacional Crédito              0    0.1   0.03 -0.013972
# Retorno Absoluto Brasil                       0    0.2    0.1 -0.012327
# Retorno Absoluto Internacional                0    0.1   0.01 -0.001674
# Renda Variável Brasil                       0.1    0.3   0.15  0.013536
# Renda Variável Internacional               0.05   0.15   0.05  0.001166
# Private Equity Brasil                         0    0.1   0.03   0.04775
# Private Equity Internacional              0.175    0.3  0.225 -0.136014
# Real Estate Brasil                            0   0.05   0.01   0.01579
# Real Estate Internacional                     0    0.1   0.03 -0.010121
# Commodities                                   0   0.05  0.005 -0.002919
#
#                                              Atual Otimizado CTR  \
# Book
# Renda Fixa Brasil CDI                     0.233557      0.233557
# Renda Fixa Brasil Crédito Pós-Fixado      0.100853      0.100853
# Renda Fixa Brasil Pré-Fixado                     0             0
# Renda Fixa Brasil Inflação                0.109807      0.109807
# Renda Fixa Internacional Cash Equivalent  0.004163      0.004163
# Renda Fixa Internacional Pré-Fixado       0.008326      0.008326
# Renda Fixa Internacional Inflação         0.002081      0.002081
# Renda Fixa Internacional Crédito          0.016028      0.016028
# Retorno Absoluto Brasil                   0.087673      0.087673
# Retorno Absoluto Internacional            0.008326      0.008326
# Renda Variável Brasil                     0.163536      0.163536
# Renda Variável Internacional              0.051166      0.051166
# Private Equity Brasil                      0.07775       0.07775
# Private Equity Internacional              0.088986      0.088986
# Real Estate Brasil                         0.02579       0.02579
# Real Estate Internacional                 0.019879      0.019879
# Commodities                               0.002081      0.002081
#
#                                          Otimizado Offset
# Book
# Renda Fixa Brasil CDI                            0.233557
# Renda Fixa Brasil Crédito Pós-Fixado             0.100853
# Renda Fixa Brasil Pré-Fixado                            0
# Renda Fixa Brasil Inflação                       0.109807
# Renda Fixa Internacional Cash Equivalent         0.004163
# Renda Fixa Internacional Pré-Fixado              0.008326
# Renda Fixa Internacional Inflação                0.002081
# Renda Fixa Internacional Crédito                 0.016028
# Retorno Absoluto Brasil                          0.087673
# Retorno Absoluto Internacional                   0.008326
# Renda Variável Brasil                            0.163536
# Renda Variável Internacional                     0.051166
# Private Equity Brasil                             0.07775
# Private Equity Internacional                     0.088986
# Real Estate Brasil                                0.02579
# Real Estate Internacional                        0.019879
# Commodities                                      0.002081

# %% [markdown]
# #### Otimização (CTR):

# %% [markdown]
# Pegando as Aplicações que não queremos mudar, baseando-se no CTR

# %%
nFilterCTR = CTR['Ativos'].iloc[:nAplicacoes].values
nAssetsCTR = CTR[~CTR['Ativos'].isin(nFilterCTR)]['Ativos'].values

dfOtimizado.insert(6, 'Mudança CTR', dfOtimizado.index.isin(nFilterCTR).astype(int))

# %% [markdown]
# Achando Pesos Ótimos do CTR

# %%
# Função Objetivo Tracking Error (Minimizar)
def trackingError(w):
    dfOtimizado['Otimizado CTR'] = w
    
    retTatico = dfRetornos1.copy()
    retTatico.set_index('Data', inplace=True)

    for index, row in dfOtimizado.iterrows():
        book = index
        currentPerc = row['Tático']
    
        retTatico[book] = retTatico[book] * currentPerc
    
    retTatico['Retorno Tático'] = retTatico.sum(axis=1)

    retAtual = dfRetornos1.copy()
    retAtual.set_index('Data', inplace=True)

    for index, row in dfOtimizado.iterrows():
        book = index
        currentPerc = row['Otimizado CTR']
    
        retAtual[book] = retAtual[book] * currentPerc
    
    retAtual['Retorno Atual'] = retAtual.sum(axis=1)

    trackingError = pd.DataFrame({
        'Retorno Atual': retAtual['Retorno Atual'],
        'Retorno Tático': retTatico['Retorno Tático']
    })
    
    trackingError['Excesso'] = trackingError['Retorno Atual'] - trackingError['Retorno Tático']

    te = trackingError['Excesso'].std()
    te = te * math.sqrt(12)
    
    return te


# Estimativas Iniciais:
initialGuess = np.array(dfOtimizado['Otimizado CTR'])


# Limites
paramRanges = [(min_val, max_val) for min_val, max_val in zip(dfOtimizado['Mínimo'], dfOtimizado['Máximo'])]


# Restrições
cons = [
    {'type': 'eq', 'fun': lambda w: np.sum(w) - 1.0}
]


# Solução:
def solve(num_fixed_params, initialGuess, paramRanges, cons):
    for i in num_fixed_params:
        paramRanges[i] = (initialGuess[i], initialGuess[i])

    result = minimize(trackingError, initialGuess, bounds=paramRanges, constraints=cons, options={'disp': True})
    return result

values_to_findCTR = nAssetsCTR
num_fixed_paramsCTR = [dfOtimizado.index.get_loc(name) for name in values_to_findCTR]

resultCTR = solve(num_fixed_paramsCTR, initialGuess, paramRanges, cons)


# Resultados
wOptimalCTR = resultCTR.x
teOptimalCTR = resultCTR.fun
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.013713790241862608
#             Iterations: 4
#             Function evaluations: 20
#             Gradient evaluations: 4

# %%
print(f'Novo Tracking Error: {teOptimalCTR:.4%}')
# Out:
# Novo Tracking Error: 1.3714%

# %%
dfOtimizado
# Out:
#                                          Mínimo Máximo Tático    Offset  \
# Book
# Renda Fixa Brasil CDI                      0.05   0.35   0.13  0.103557
# Renda Fixa Brasil Crédito Pós-Fixado          0    0.2   0.09  0.010853
# Renda Fixa Brasil Pré-Fixado                  0    0.1      0         0
# Renda Fixa Brasil Inflação                    0   0.15   0.12 -0.010193
# Renda Fixa Internacional Cash Equivalent      0   0.05  0.005 -0.000837
# Renda Fixa Internacional Pré-Fixado           0   0.05   0.01 -0.001674
# Renda Fixa Internacional Inflação             0   0.05  0.005 -0.002919
# Renda Fixa Internacional Crédito              0    0.1   0.03 -0.013972
# Retorno Absoluto Brasil                       0    0.2    0.1 -0.012327
# Retorno Absoluto Internacional                0    0.1   0.01 -0.001674
# Renda Variável Brasil                       0.1    0.3   0.15  0.013536
# Renda Variável Internacional               0.05   0.15   0.05  0.001166
# Private Equity Brasil                         0    0.1   0.03   0.04775
# Private Equity Internacional              0.175    0.3  0.225 -0.136014
# Real Estate Brasil                            0   0.05   0.01   0.01579
# Real Estate Internacional                     0    0.1   0.03 -0.010121
# Commodities                                   0   0.05  0.005 -0.002919
#
#                                              Atual  Otimizado CTR  \
# Book
# Renda Fixa Brasil CDI                     0.233557       0.233557
# Renda Fixa Brasil Crédito Pós-Fixado      0.100853       0.100853
# Renda Fixa Brasil Pré-Fixado                     0       0.000000
# Renda Fixa Brasil Inflação                0.109807       0.136284
# Renda Fixa Internacional Cash Equivalent  0.004163       0.004163
# Renda Fixa Internacional Pré-Fixado       0.008326       0.008326
# Renda Fixa Internacional Inflação         0.002081       0.002081
# Renda Fixa Internacional Crédito          0.016028       0.016028
# Retorno Absoluto Brasil                   0.087673       0.087673
# Retorno Absoluto Internacional            0.008326       0.008326
# Renda Variável Brasil                     0.163536       0.143909
# Renda Variável Internacional              0.051166       0.078452
# Private Equity Brasil                      0.07775       0.043614
# Private Equity Internacional              0.088986       0.088986
# Real Estate Brasil                         0.02579       0.025790
# Real Estate Internacional                 0.019879       0.019879
# Commodities                               0.002081       0.002081
#
#                                           Mudança CTR Otimizado Offset
# Book
# Renda Fixa Brasil CDI                               0         0.233557
# Renda Fixa Brasil Crédito Pós-Fixado                0         0.100853
# Renda Fixa Brasil Pré-Fixado                        0                0
# Renda Fixa Brasil Inflação                          1         0.109807
# Renda Fixa Internacional Cash Equivalent            0         0.004163
# Renda Fixa Internacional Pré-Fixado                 0         0.008326
# Renda Fixa Internacional Inflação                   0         0.002081
# Renda Fixa Internacional Crédito                    0         0.016028
# Retorno Absoluto Brasil                             0         0.087673
# Retorno Absoluto Internacional                      0         0.008326
# Renda Variável Brasil                               1         0.163536
# Renda Variável Internacional                        1         0.051166
# Private Equity Brasil                               1          0.07775
# Private Equity Internacional                        0         0.088986
# Real Estate Brasil                                  0          0.02579
# Real Estate Internacional                           0         0.019879
# Commodities                                         0         0.002081

# %% [markdown]
# #### Otimização (Offset):

# %% [markdown]
# Pegando as Aplicações que não queremos mudar, baseando-se no Offset

# %%
nFilterOffset = dfOffset['Offset'].iloc[:nAplicacoes].values
nAssetsOffset = dfOffset[~dfOffset['Offset'].isin(nFilterOffset)]['Offset'].index

dfOtimizado['Mudança Offset'] = np.where(dfOtimizado['Offset'].isin(nFilterOffset), 1, 0)

# %% [markdown]
# Achando Pesos Ótimos do Offset

# %%
# Função Objetivo Tracking Error (Minimizar)
def trackingError(w):
    dfOtimizado['Otimizado Offset'] = w
    
    retTatico = dfRetornos1.copy()
    retTatico.set_index('Data', inplace=True)

    for index, row in dfOtimizado.iterrows():
        book = index
        currentPerc = row['Tático']
        # print(book, currentPerc, retTatico[book])
    
        retTatico[book] = retTatico[book] * currentPerc
    
    retTatico['Retorno Tático'] = retTatico.sum(axis=1)

    retAtual = dfRetornos1.copy()
    retAtual.set_index('Data', inplace=True)

    for index, row in dfOtimizado.iterrows():
        book = index
        currentPerc = row['Otimizado Offset']
    
        retAtual[book] = retAtual[book] * currentPerc
    
    retAtual['Retorno Atual'] = retAtual.sum(axis=1)

    trackingError = pd.DataFrame({
        'Retorno Atual': retAtual['Retorno Atual'],
        'Retorno Tático': retTatico['Retorno Tático']
    })
    
    trackingError['Excesso'] = trackingError['Retorno Atual'] - trackingError['Retorno Tático']

    te = trackingError['Excesso'].std()
    te = te * math.sqrt(12)
    
    return te


# Estimativas Iniciais:
initialGuess = np.array(dfOtimizado['Otimizado Offset'])


# Limites
paramRanges = [(min_val, max_val) for min_val, max_val in zip(dfOtimizado['Mínimo'], dfOtimizado['Máximo'])]


# Restrições
cons = [
    {'type': 'eq', 'fun': lambda w: np.sum(w) - 1.0}
]


# Solução:
def solve(num_fixed_params, initialGuess, paramRanges, cons):
    for i in num_fixed_params:
        paramRanges[i] = (initialGuess[i], initialGuess[i])

    result = minimize(trackingError, initialGuess, bounds=paramRanges, constraints=cons, options={'disp': True})
    return result

values_to_findOffset = nAssetsOffset
num_fixed_paramsOffset = [dfOtimizado.index.get_loc(name) for name in values_to_findOffset]

resultOffset = solve(num_fixed_paramsOffset, initialGuess, paramRanges, cons)


# Resultados
wOptimalOffset = resultOffset.x
teOptimalOffset = resultOffset.fun
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.002461164524020437
#             Iterations: 7
#             Function evaluations: 39
#             Gradient evaluations: 7

# %%
print(f'Novo Tracking Error: {teOptimalOffset:.4%}')
# Out:
# Novo Tracking Error: 0.2461%

# %%
dfOtimizado
# Out:
#                                          Mínimo Máximo Tático    Offset  \
# Book
# Renda Fixa Brasil CDI                      0.05   0.35   0.13  0.103557
# Renda Fixa Brasil Crédito Pós-Fixado          0    0.2   0.09  0.010853
# Renda Fixa Brasil Pré-Fixado                  0    0.1      0         0
# Renda Fixa Brasil Inflação                    0   0.15   0.12 -0.010193
# Renda Fixa Internacional Cash Equivalent      0   0.05  0.005 -0.000837
# Renda Fixa Internacional Pré-Fixado           0   0.05   0.01 -0.001674
# Renda Fixa Internacional Inflação             0   0.05  0.005 -0.002919
# Renda Fixa Internacional Crédito              0    0.1   0.03 -0.013972
# Retorno Absoluto Brasil                       0    0.2    0.1 -0.012327
# Retorno Absoluto Internacional                0    0.1   0.01 -0.001674
# Renda Variável Brasil                       0.1    0.3   0.15  0.013536
# Renda Variável Internacional               0.05   0.15   0.05  0.001166
# Private Equity Brasil                         0    0.1   0.03   0.04775
# Private Equity Internacional              0.175    0.3  0.225 -0.136014
# Real Estate Brasil                            0   0.05   0.01   0.01579
# Real Estate Internacional                     0    0.1   0.03 -0.010121
# Commodities                                   0   0.05  0.005 -0.002919
#
#                                              Atual  Otimizado CTR  \
# Book
# Renda Fixa Brasil CDI                     0.233557       0.233557
# Renda Fixa Brasil Crédito Pós-Fixado      0.100853       0.100853
# Renda Fixa Brasil Pré-Fixado                     0       0.000000
# Renda Fixa Brasil Inflação                0.109807       0.136284
# Renda Fixa Internacional Cash Equivalent  0.004163       0.004163
# Renda Fixa Internacional Pré-Fixado       0.008326       0.008326
# Renda Fixa Internacional Inflação         0.002081       0.002081
# Renda Fixa Internacional Crédito          0.016028       0.016028
# Retorno Absoluto Brasil                   0.087673       0.087673
# Retorno Absoluto Internacional            0.008326       0.008326
# Renda Variável Brasil                     0.163536       0.143909
# Renda Variável Internacional              0.051166       0.078452
# Private Equity Brasil                      0.07775       0.043614
# Private Equity Internacional              0.088986       0.088986
# Real Estate Brasil                         0.02579       0.025790
# Real Estate Internacional                 0.019879       0.019879
# Commodities                               0.002081       0.002081
#
#                                           Mudança CTR  Otimizado Offset  \
# Book
# Renda Fixa Brasil CDI                               0          0.156645
# Renda Fixa Brasil Crédito Pós-Fixado                0          0.100853
# Renda Fixa Brasil Pré-Fixado                        0          0.000000
# Renda Fixa Brasil Inflação                          1          0.109807
# Renda Fixa Internacional Cash Equivalent            0          0.004163
# Renda Fixa Internacional Pré-Fixado                 0          0.008326
# Renda Fixa Internacional Inflação                   0          0.002081
# Renda Fixa Internacional Crédito                    0          0.016028
# Retorno Absoluto Brasil                             0          0.087673
# Retorno Absoluto Internacional                      0          0.008326
# Renda Variável Brasil                               1          0.163536
# Renda Variável Internacional                        1          0.051166
# Private Equity Brasil                               1          0.028009
# Private Equity Internacional                        0          0.228279
# Real Estate Brasil                                  0          0.013149
# Real Estate Internacional                           0          0.019879
# Commodities                                         0          0.002081
#
#                                           Mudança Offset
# Book
# Renda Fixa Brasil CDI                                  1
# Renda Fixa Brasil Crédito Pós-Fixado                   0
# Renda Fixa Brasil Pré-Fixado                           0
# Renda Fixa Brasil Inflação                             0
# Renda Fixa Internacional Cash Equivalent               0
# Renda Fixa Internacional Pré-Fixado                    0
# Renda Fixa Internacional Inflação                      0
# Renda Fixa Internacional Crédito                       0
# Retorno Absoluto Brasil                                0
# Retorno Absoluto Internacional                         0
# Renda Variável Brasil                                  0
# Renda Variável Internacional                           0
# Private Equity Brasil                                  1
# Private Equity Internacional                           1
# Real Estate Brasil                                     1
# Real Estate Internacional                              0
# Commodities                                            0

# %% [markdown]
# ## Resultados

# %% [markdown]
# Tabela de Resultados do Rebalanceamento

# %%
dfResultados = dfOtimizado.copy()

otimizacoes = ['CTR', 'Offset']

for otimizacao in otimizacoes:
    acao = []
    for index, row in dfResultados.iterrows():
        text = ''
        percDiff = row[f'Otimizado {otimizacao}'] - row['Atual']
        newValue = abs(percDiff) * valorCarteira
        assetValue = locale.format_string("%.3f", newValue, grouping=True, monetary=True)
        
        if percDiff < 0:
            text += f'Vender {assetValue}'
    
        elif percDiff > 0:
            text += f'Comprar {assetValue}'
    
        else:
            text += '-'
    
        acao.append(text)

    dfResultados[f'Ação {otimizacao}'] = acao

dfResultados = dfResultados[['Mínimo', 'Máximo', 'Tático', 'Offset', 'Atual', 'Otimizado CTR', 'Mudança CTR', 'Ação CTR', 'Otimizado Offset', 'Mudança Offset', 'Ação Offset']]

dfResultados
# Out:
#                                          Mínimo Máximo Tático    Offset  \
# Book
# Renda Fixa Brasil CDI                      0.05   0.35   0.13  0.103557
# Renda Fixa Brasil Crédito Pós-Fixado          0    0.2   0.09  0.010853
# Renda Fixa Brasil Pré-Fixado                  0    0.1      0         0
# Renda Fixa Brasil Inflação                    0   0.15   0.12 -0.010193
# Renda Fixa Internacional Cash Equivalent      0   0.05  0.005 -0.000837
# Renda Fixa Internacional Pré-Fixado           0   0.05   0.01 -0.001674
# Renda Fixa Internacional Inflação             0   0.05  0.005 -0.002919
# Renda Fixa Internacional Crédito              0    0.1   0.03 -0.013972
# Retorno Absoluto Brasil                       0    0.2    0.1 -0.012327
# Retorno Absoluto Internacional                0    0.1   0.01 -0.001674
# Renda Variável Brasil                       0.1    0.3   0.15  0.013536
# Renda Variável Internacional               0.05   0.15   0.05  0.001166
# Private Equity Brasil                         0    0.1   0.03   0.04775
# Private Equity Internacional              0.175    0.3  0.225 -0.136014
# Real Estate Brasil                            0   0.05   0.01   0.01579
# Real Estate Internacional                     0    0.1   0.03 -0.010121
# Commodities                                   0   0.05  0.005 -0.002919
#
#                                              Atual  Otimizado CTR  \
# Book
# Renda Fixa Brasil CDI                     0.233557       0.233557
# Renda Fixa Brasil Crédito Pós-Fixado      0.100853       0.100853
# Renda Fixa Brasil Pré-Fixado                     0       0.000000
# Renda Fixa Brasil Inflação                0.109807       0.136284
# Renda Fixa Internacional Cash Equivalent  0.004163       0.004163
# Renda Fixa Internacional Pré-Fixado       0.008326       0.008326
# Renda Fixa Internacional Inflação         0.002081       0.002081
# Renda Fixa Internacional Crédito          0.016028       0.016028
# Retorno Absoluto Brasil                   0.087673       0.087673
# Retorno Absoluto Internacional            0.008326       0.008326
# Renda Variável Brasil                     0.163536       0.143909
# Renda Variável Internacional              0.051166       0.078452
# Private Equity Brasil                      0.07775       0.043614
# Private Equity Internacional              0.088986       0.088986
# Real Estate Brasil                         0.02579       0.025790
# Real Estate Internacional                 0.019879       0.019879
# Commodities                               0.002081       0.002081
#
#                                           Mudança CTR             Ação CTR  \
# Book
# Renda Fixa Brasil CDI                               0                    -
# Renda Fixa Brasil Crédito Pós-Fixado                0                    -
# Renda Fixa Brasil Pré-Fixado                        0                    -
# Renda Fixa Brasil Inflação                          1  Comprar 325.560,929
# Renda Fixa Internacional Cash Equivalent            0                    -
# Renda Fixa Internacional Pré-Fixado                 0                    -
# Renda Fixa Internacional Inflação                   0                    -
# Renda Fixa Internacional Crédito                    0                    -
# Retorno Absoluto Brasil                             0                    -
# Retorno Absoluto Internacional                      0                    -
# Renda Variável Brasil                               1   Vender 241.333,841
# Renda Variável Internacional                        1  Comprar 335.508,901
# Private Equity Brasil                               1   Vender 419.735,806
# Private Equity Internacional                        0                    -
# Real Estate Brasil                                  0                    -
# Real Estate Internacional                           0                    -
# Commodities                                         0                    -
#
#                                           Otimizado Offset  Mudança Offset  \
# Book
# Renda Fixa Brasil CDI                             0.156645               1
# Renda Fixa Brasil Crédito Pós-Fixado              0.100853               0
# Renda Fixa Brasil Pré-Fixado                      0.000000               0
# Renda Fixa Brasil Inflação                        0.109807               0
# Renda Fixa Internacional Cash Equivalent          0.004163               0
# Renda Fixa Internacional Pré-Fixado               0.008326               0
# Renda Fixa Internacional Inflação                 0.002081               0
# Renda Fixa Internacional Crédito                  0.016028               0
# Retorno Absoluto Brasil                           0.087673               0
# Retorno Absoluto Internacional                    0.008326               0
# Renda Variável Brasil                             0.163536               0
# Renda Variável Internacional                      0.051166               0
# Private Equity Brasil                             0.028009               1
# Private Equity Internacional                      0.228279               1
# Real Estate Brasil                                0.013149               1
# Real Estate Internacional                         0.019879               0
# Commodities                                       0.002081               0
#
#                                                     Ação Offset
# Book
# Renda Fixa Brasil CDI                        Vender 945.697,525
# Renda Fixa Brasil Crédito Pós-Fixado                          -
# Renda Fixa Brasil Pré-Fixado                                  -
# Renda Fixa Brasil Inflação                                    -
# Renda Fixa Internacional Cash Equivalent                      -
# Renda Fixa Internacional Pré-Fixado                           -
# Renda Fixa Internacional Inflação                             -
# Renda Fixa Internacional Crédito                              -
# Retorno Absoluto Brasil                                       -
# Retorno Absoluto Internacional                                -
# Renda Variável Brasil                                         -
# Renda Variável Internacional                                  -
# Private Equity Brasil                        Vender 611.611,885
# Private Equity Internacional              Comprar 1.712.735,757
# Real Estate Brasil                           Vender 155.426,165
# Real Estate Internacional                                     -
# Commodities                                                   -

# %% [markdown]
# Tabela dos Tracking Errors

# %%
data = {
    '': ['Tracking Error[%]'],
    'Atual': [te*100],
    'CTR': [teOptimalCTR*100],
    'Offset': [teOptimalOffset*100]
}

dfTableTE = pd.DataFrame(data)
dfTableTE.set_index('', inplace=True)

dfTableTE
# Out:
#                       Atual       CTR    Offset
#
# Tracking Error[%]  1.668571  1.371379  0.246116

# %% [markdown]
# Convertendo um Excel de Output

# %%
def send_notification(title, message):
    notification.notify(
        title=title,
        message=message,
        timeout=10  # Notification will disappear after 10 seconds
    )

excelName = portfolioCliente.split('.')[0]

if os.path.exists(f'{PATH}/Resultados'):
    pass
else:
    os.mkdir(f'{PATH}/Resultados')

excel_file_path = f'{PATH}/Resultados/Resultados ({excelName}).xlsx'

# Send Notification Status
try:
    with pd.ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
        dfResultados.to_excel(writer, sheet_name='Rebalanceamento')
        dfTableTE.to_excel(writer, sheet_name='Tracking Error')
    
    send_notification("Success!", f"Excel File ({excelName}) Created")

except:
    send_notification("Warning!", "Feche o Excel Antes de Rodar o Código")

# %% [markdown]
# <br>

# %% [markdown]
# ---

# %%
send_notification("Warning!", "Feche o Excel Antes de Rodar o Código")

# %% [markdown]
# <br>
