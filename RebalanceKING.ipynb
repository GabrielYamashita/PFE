# %% [markdown]
# # Rebalanceamento de Carteira:

# %% [markdown]
# ### Import de Bibliotecas:

# %%
import re
import locale
import numpy as np
import pandas as pd
from skimage.measure import label, regionprops

pd.options.mode.chained_assignment = None  # default='warn'
locale.setlocale(locale.LC_ALL, 'pt-BR.utf-8')
# Out:
# 'pt-BR.utf-8'

# %% [markdown]
# ### Leitura dos Excels:

# %%
path = './src'

# %%
carteira = pd.read_excel(f'{path}/Clientes/Portfolio Global - KING.xlsx', sheet_name='Carteira Global', header=None)
politica = pd.read_excel(f'{path}/Clientes/Portfolio Global - KING.xlsx', sheet_name='Política de Investimento', header=None)

database = pd.read_excel(f'{path}/New_query_2023_11_16 (1).xlsx', sheet_name='result', header=None)

# %% [markdown]
# ### Extração de Tabelas e Atribuição de Variáveis Dataframe

# %% [markdown]
# #### Análise de Tabelas dentro de cada Excel:

# %%
def getTables(df):
    larr = label(np.array(df.notnull()).astype("int"))
    
    list_dfs = []
    
    for s in regionprops(larr):
        sub_df = df.iloc[
            s.bbox[0]:s.bbox[2], s.bbox[1]:s.bbox[3]
        ].pipe(
            lambda df_: df_.rename(columns=df_.iloc[0]).drop(df_.index[0])
        )
    
        list_dfs.append(sub_df)
    return list_dfs

# %%
database
# Out:
#                       0                                 1  \
# 0             ClassName                 ClassLevelTwoName
# 1      Retorno Absoluto           Retorno Absoluto Brasil
# 2        Renda Variável          Renda Variável Doméstico
# 3            Renda Fixa             Renda Fixa Brasil CDI
# 4      Retorno Absoluto           Retorno Absoluto Brasil
# ..                  ...                               ...
# 745          Renda Fixa             Renda Fixa Brasil CDI
# 746          Renda Fixa             Renda Fixa Brasil CDI
# 747  Fundos Balanceados  Fundos Balanceados Internacional
# 748  Fundos Balanceados  Fundos Balanceados Internacional
# 749      Private Equity      Private Equity Internacional
#
#                                                  2  \
# 0                              ClassLevelThreeName
# 1                    Retorno Absoluto Brasil Macro
# 2                   Renda Variável Doméstico Ações
# 3                               RF BR CDI Soberano
# 4                    Retorno Absoluto Brasil Macro
# ..                                             ...
# 745                             RF BR CDI Bancário
# 746                             RF BR CDI Bancário
# 747  Fundos Balanceados Internacional Veículo Jera
# 748  Fundos Balanceados Internacional Veículo Jera
# 749   Private Equity Internacional Multiestratégia
#
#                                           3                       4  \
# 0                                      Name      InvestmentTypeName
# 1                  Ibiuna Hedge STH FIC FIM          InvestmentFund
# 2                   Bogari Value JC FIC FIA          InvestmentFund
# 3    BTG Pactual Tesouro Selic FI RF REF DI          InvestmentFund
# 4                     Kapitalo Zeta FIQ FIM          InvestmentFund
# ..                                      ...                     ...
# 745         LIG Itaú 99.00 % CDI 2024-02-01                    Bond
# 746     LCA Bradesco 94.50 % CDI 2025-08-19                    Bond
# 747      Jera - JWM Liquid SP II- L-U- 0923  InvestmentFundOffShore
# 748      Jera - JWM Liquid SP II- L-U- 0823  InvestmentFundOffShore
# 749   Jera - JWM Illiquid SP III- I-U- 1123  InvestmentFundOffShore
#
#                                         5  \
# 0    RedemptionQuotationDelayDayCountName
# 1                           Dias Corridos
# 2                           Dias Corridos
# 3                           Dias Corridos
# 4                              Dias Úteis
# ..                                    ...
# 745                            Dias Úteis
# 746                            Dias Úteis
# 747                         Dias Corridos
# 748                         Dias Corridos
# 749                         Dias Corridos
#
#                                          6  \
# 0    RedemptionQuotationDelayDayCountValue
# 1                                       30
# 2                                       30
# 3                                        0
# 4                                       60
# ..                                     ...
# 745                                      0
# 746                                      0
# 747                                     30
# 748                                     30
# 749                                     30
#
#                                            7                   8
# 0                               ExternalCode  ExternalCodeSource
# 1                   IBIUNA HEDGE STH FIC FIM             Lote 45
# 2                     BOGARI VALE JC FIC FIM             Lote 45
# 3                        TESOURO SELIC FI RF             Lote 45
# 4                          KAPITALO FIQ ZETA             Lote 45
# ..                                       ...                 ...
# 745        LIG 29Sep2023 - 01Feb2024 99 ITAU             Lote 45
# 746  LCA 30Aug2023 - 19Aug2025 94.5 BRADESCO             Lote 45
# 747                JWM LIQUID SP II L-U 0923             Lote 45
# 748                JWM LIQUID SP II L-U 0823             Lote 45
# 749             JWM ILLIQUID SP III I-U 1123             Lote 45
#
# [750 rows x 9 columns]

# %%
dfsCarteira = getTables(carteira)
dfsPolitica = getTables(politica)
dfsDatabase = getTables(database)

# %% [markdown]
# #### Criando Variáveis para cada Tabela dos Excels

# %%
def attrDataframes(list_dfs):
    def getVarName(df):
        def namestr(obj, namespace):
            return [name for name in namespace if namespace[name] is obj]
    
        return namestr(df, globals())[0]
    
    for i in range(len(list_dfs)):
        dfName = getVarName(list_dfs).replace('dfs', '')
        
        varName = f'df{dfName}{i+1}'
        value = list_dfs[i]
        globals()[varName] = value
        
        print(f'- Dataframe {varName} created.')
    print('')

# %%
attrDataframes(dfsCarteira)
attrDataframes(dfsPolitica)
attrDataframes(dfsDatabase)
# Out:
# - Dataframe dfCarteira1 created.
#
# - Dataframe dfPolitica1 created.
# - Dataframe dfPolitica2 created.
# - Dataframe dfPolitica3 created.
#
# - Dataframe dfDatabase1 created.

# %% [markdown]
# ### Dataframes:

# %% [markdown]
# #### - Carteira:

# %%
valorCarteira = dfCarteira1["Financeiro"].iloc[-1]
perctCarteira = dfCarteira1["%"].iloc[-1]

# %%
dfCarteira1 = dfCarteira1.dropna(subset=["Source"])
dfCarteira1 = dfCarteira1.dropna(subset=["Portfólio"])

# %%
dfCarteira1.head()
# Out:
#           Data Posição               Source  \
# 5  2023-09-13 00:00:00           KING - BRL
# 6  2023-09-13 00:00:00           KING - BRL
# 7  2023-09-13 00:00:00           KING - BRL
# 8  2023-09-13 00:00:00           KING - BRL
# 9  2023-09-13 00:00:00  KING KONG FIM CP IE
#
#                                          Portfólio     Quantidade  \
# 5                             BV CASH FIRF SIMPLES   21170.299483
# 6  BTG PACTUAL DIGITAL TESOURO SELIC SIMPLES FI RF  218395.712765
# 7          LCI 30Jun2023 - 20Jun2025 96.5 BRADESCO         800000
# 8          LCA 30Aug2023 - 19Aug2025 94.5 BRADESCO        1000000
# 9                                      LFT01092026             38
#
#        Financeiro                        Classe         %
# 5    26943.031989  Renda Fixa Brasil Pós Fixado  0.002191
# 6    315562.17117  Renda Fixa Brasil Pós Fixado  0.025664
# 7   820257.249879  Renda Fixa Brasil Pós Fixado   0.06671
# 8  1004178.335827  Renda Fixa Brasil Pós Fixado  0.081668
# 9   264782.350653  Renda Fixa Brasil Pós Fixado  0.021534

# %% [markdown]
# #### - Política:

# %%
dfPolitica1.head()
# Out:
#   TradingDesk                              Book   Min   Max Estratégico  \
# 1  KING - BRL          Renda Fixa BR Pós-Fixado  0.05  0.35       0.075
# 2  KING - BRL     Renda Fixa BR Crédito Privado     0   0.2        0.09
# 3  KING - BRL          Renda Fixa BR Pré-Fixado     0   0.1        0.04
# 4  KING - BRL            Renda Fixa BR Inflação     0  0.15        0.08
# 5  KING - BRL   Renda Fixa Intl Cash Equivalent     0  0.05           0
#
#   Tático     Atual
# 1   0.13  0.233557
# 2   0.09  0.100853
# 3      0         0
# 4   0.12  0.109807
# 5  0.005  0.004163

# %%
dfPolitica2.rename(columns={'%':'Estratégico'}, inplace=True)
dfPolitica2.head()
# Out:
#    Alocação Estratégica por Mercado Estratégico
# 23                       Renda Fixa       0.315
# 24                 Retorno Absoluto        0.15
# 25                   Renda Variável       0.225
# 26                   Private Equity       0.255
# 27                      Real Estate       0.055

# %%
dfPolitica3.head()
# Out:
#    Alocação Estratégica por Geografia      %
# 31                             Brasil  0.575
# 32                      Internacional  0.425

# %% [markdown]
# #### - Database:

# %%
dfDatabase1.head()
# Out:
#           ClassName         ClassLevelTwoName  \
# 1  Retorno Absoluto   Retorno Absoluto Brasil
# 2    Renda Variável  Renda Variável Doméstico
# 3        Renda Fixa     Renda Fixa Brasil CDI
# 4  Retorno Absoluto   Retorno Absoluto Brasil
# 5  Retorno Absoluto   Retorno Absoluto Brasil
#
#                     ClassLevelThreeName  \
# 1         Retorno Absoluto Brasil Macro
# 2        Renda Variável Doméstico Ações
# 3                    RF BR CDI Soberano
# 4         Retorno Absoluto Brasil Macro
# 5  Retorno Absoluto Brasil Equity Hedge
#
#                                      Name InvestmentTypeName  \
# 1                Ibiuna Hedge STH FIC FIM     InvestmentFund
# 2                 Bogari Value JC FIC FIA     InvestmentFund
# 3  BTG Pactual Tesouro Selic FI RF REF DI     InvestmentFund
# 4                   Kapitalo Zeta FIQ FIM     InvestmentFund
# 5       Moat Capital Equity Hedge FIC FIM     InvestmentFund
#
#   RedemptionQuotationDelayDayCountName RedemptionQuotationDelayDayCountValue  \
# 1                        Dias Corridos                                    30
# 2                        Dias Corridos                                    30
# 3                        Dias Corridos                                     0
# 4                           Dias Úteis                                    60
# 5                           Dias Úteis                                     0
#
#                         ExternalCode ExternalCodeSource
# 1           IBIUNA HEDGE STH FIC FIM            Lote 45
# 2             BOGARI VALE JC FIC FIM            Lote 45
# 3                TESOURO SELIC FI RF            Lote 45
# 4                  KAPITALO FIQ ZETA            Lote 45
# 5  MOAT CAPITAL EQUITY HEDGE FIC FIM            Lote 45

# %% [markdown]
# ### Rebalanceamento

# %% [markdown]
# #### Pegando Ativos da Carteira

# %%
result_list = dfCarteira1['Portfólio'].dropna().to_list()

result_list
# Out:
# ['BV CASH FIRF SIMPLES',
#  'BTG PACTUAL DIGITAL TESOURO SELIC SIMPLES FI RF',
#  'LCI 30Jun2023 - 20Jun2025 96.5 BRADESCO',
#  'LCA 30Aug2023 - 19Aug2025 94.5 BRADESCO',
#  'LFT01092026',
#  'TESOURO SELIC FI RF',
#  'JWM CREDITO FIM CP',
#  'JWM INFLAÇÃO FIM CP',
#  'JWM MULTIMERCADO FIM IE',
#  'BOVA11',
#  'JWM AÇÕES FIA',
#  'MAESTRO FIA',
#  'IVVB11',
#  'NOVA RAPOSO FIP',
#  'JWM VANQUISH FIM CP IE',
#  'SPECTRA NIMBUS FIP',
#  'JWM ILLIQUID SP III',
#  'GTWR11 - FII G TOWERS CI',
#  'FII VOTORANTIM LECREC',
#  'JWM LIQUID SP II',
#  'WDOV23']

# %%
filterWords = {}

for benchmark in dfDatabase1["Benchmark"].unique():
    dfFiltrado = dfDatabase1[dfDatabase1["Benchmark"] == benchmark][["AssetClassName", "AssetName", "Benchmark"]]
    
    dfFiltrado["AssetClassName"] = dfFiltrado["AssetClassName"].astype(str).str.lower().apply(lambda x: re.sub(r'\d+', '', x))
    dfFiltrado["AssetName"] = dfFiltrado["AssetName"].astype(str).str.lower().apply(lambda x: re.sub(r'\d+', '', x))
    
    colunas = dfFiltrado[["AssetClassName", "AssetName"]]
    words = ' '.join(colunas.values.flatten()).split()
    words = list(set(words))

    filterWords[benchmark] = words

# filterWords
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.pyenv\pyenv-win\versions\3.9.13\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\.pyenv\pyenv-win\versions\3.9.13\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.pyenv\pyenv-win\versions\3.9.13\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Benchmark'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 filterWords = {}
# ----> 3 for benchmark in dfDatabase1["Benchmark"].unique():
#       4     dfFiltrado = dfDatabase1[dfDatabase1["Benchmark"] == benchmark][["AssetClassName", "AssetName", "Benchmark"]]
#       6     dfFiltrado["AssetClassName"] = dfFiltrado["AssetClassName"].astype(str).str.lower().apply(lambda x: re.sub(r'\d+', '', x))
#
# File ~\.pyenv\pyenv-win\versions\3.9.13\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\.pyenv\pyenv-win\versions\3.9.13\lib\site-packages\pandas\core\indexes\base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Benchmark'

# %%
# Create a set for each list
list_sets = {key: set(value) for key, value in filterWords.items()}

# Find unique words in each list that do not appear in other lists
unique_words_dict = {key: list(word_set - set.union(*(list_sets[k] for k in list_sets if k != key))) for key, word_set in list_sets.items()}

# Print the result
for key, unique_words in unique_words_dict.items():
    print(f'{key}: {unique_words}\n')

# %% [markdown]
# #### Categorizando cada Ativo com seu Benchmark

# %%
'''
Dúvidas:
FII = IFIX ou CDI
FIP = IBOVESPA OU IFIX
NOVA RAPOSA FIP = IBOV
CASH ou SIMPLES = CDI
LECREC = IFIX
'''

# CDI
# substringsCDI = ['tesouro', 'lci', 'lft', 'lca', 'credito fim cp']
substringsCDI = unique_words_dict["CDI"]
patternsCDI = '|'.join(substringsCDI)

# DOLAR
# substringsDOLAR = []
substringsDOLAR = unique_words_dict["DOLAR"]
patternsDOLAR = '|'.join(substringsDOLAR)

# HASH11
# substringsHASH = []
substringsHASH = unique_words_dict["HASH11"]
patternsHASH = '|'.join(substringsHASH)

# IBOVESPA
# substringsIBOV = ['fia']
substringsIBOV = unique_words_dict["IBOVESPA"]
patternsIBOV = '|'.join(substringsIBOV)

# ICB
# substringsICB = []
substringsICB = unique_words_dict["ICB"]
patternsICB = '|'.join(substringsICB)

# IFIX
# substringsIFIX = []
substringsIFIX = unique_words_dict["IFIX"]
patternsIFIX = '|'.join(substringsIFIX)

# S&P500
# substringsSP500 = ['illiquid', 'liquid']
substringsSP500 = unique_words_dict["S&P500"]
patternsSP500 = '|'.join(substringsSP500)

# %%
def matchFund(target, filter):    
    return any(substring in target.split() for substring in filter)

# %%
cont = 0
benchmarks = []

for i in result_list:
    source = dfDatabase1['AssetName'].astype(str).str.lower().apply(lambda x: re.sub(r'\d+', '', x))
    search  = re.sub(r'\d+', '', i.lower())
    
    result = dfDatabase1[source == search][['Benchmark', 'AssetName']]
    
    if not result.empty:
        cont += 1
        benchmarks.append(result['Benchmark'].iloc[0])
        # print(result['Benchmark'].iloc[0])
        
    elif matchFund(search, substringsCDI):
        cont+=1
        benchmarks.append('CDI')
        # print('CDI')

    elif 'credito fim cp' in search:
        cont+=1
        benchmarks.append('CDI')
        
    elif matchFund(search, substringsDOLAR):
        cont+=1
        benchmarks.append('DOLAR')
        # print('DOLAR')

    elif 'wdo' in search:
        cont+=1
        benchmarks.append('DOLAR')
        
        
    elif matchFund(search, substringsHASH):
        cont+=1
        benchmarks.append('HASH11')
        # print('HASH11')
        
    elif matchFund(search, substringsIBOV):
        cont+=1
        benchmarks.append('IBOVESPA')
        # print('IBOVESPA')
        
    elif matchFund(search, substringsICB):
        cont+=1
        benchmarks.append('ICB')
        # print('ICB')
        
    elif matchFund(search, substringsIFIX):
        cont+=1
        benchmarks.append('IFIX')
        # print('IFIX')

    elif 'fii g towers ci' in search:
        cont+=1
        benchmarks.append('IFIX')
        
    elif matchFund(search, substringsSP500):
        cont+=1
        benchmarks.append('S&P500')
        # print('S&P500')
        
    else:
        benchmarks.append(np.nan)
        print(f"NÃO PASSEI | {search}")

    

print(f"{cont/len(result_list):.2%}")
benchmarks

# %%
try:
    dfCarteira1.insert(2, 'Benchmarks', benchmarks)
except:
    pass

dfCarteira1

# %% [markdown]
# #### Agrupando os Benchmarks

# %%
groupedBenchmarks = dfCarteira1.groupby('Benchmarks')['%'].sum().reset_index()
groupedBenchmarks = groupedBenchmarks.rename(columns={'%':'Atual'})

groupedBenchmarks

# %% [markdown]
# #### Comparando Atual x Target

# %%
def groupBySubstring(value):
    substrings = ['Renda Fixa', 'Retorno Absoluto', 'Renda Variável', 'Private Equity', 'Real Estate', 'Commodities']

    for substring in substrings:
        if substring in value:
            return substring

# %%
dfPolitica1["BookName"] = dfPolitica1["Book"].apply(groupBySubstring)

# %%
dicionario = {
    'CDI':'Renda Fixa',
    'IBOVESPA':'Retorno Absoluto',
    'S&P500':'Renda Variável',
    'IFIX':'Private Equity',
    'IFIX':'Real Estate',
    'ICB':'Commodities'
}

groupedBenchmarks['Benchmarks'] = groupedBenchmarks['Benchmarks'].map(dicionario)

groupedBenchmarks

# %%
tatico = dfPolitica1.groupby('BookName')['Tático'].sum().reset_index()
tatico = tatico.rename(columns={'BookName':'Alocação Estratégica por Mercado'})
# groupedBenchmarks = groupedBenchmarks.rename(columns={'%':'Atual'})

tatico

# %%
dfRebalanced = dfPolitica2.merge(groupedBenchmarks, how='left', left_on='Alocação Estratégica por Mercado', right_on='Benchmarks')
dfRebalanced = pd.merge(dfRebalanced, tatico, on="Alocação Estratégica por Mercado")

dfRebalanced.drop(columns=['Benchmarks'], inplace=True)
dfRebalanced['Atual'].fillna(0, inplace=True)

dfRebalanced['Offset (Estratégico)'] = dfRebalanced['Estratégico'] - dfRebalanced['Atual']
dfRebalanced['Offset (Tático)'] = dfRebalanced['Tático'] - dfRebalanced['Atual']

dfRebalanced = dfRebalanced[["Alocação Estratégica por Mercado", "Atual", "Estratégico", "Offset (Estratégico)", "Tático", "Offset (Tático)"]]

dfRebalanced

# %% [markdown]
# #### Tracking Error:

# %%
# # ADAPTAR PARA OS FUNDOS

# import numpy as np
# import yfinance as yf
# from datetime import datetime, timedelta

# def get_returns(ticker, period):
#     start_date = (datetime.today() - timedelta(days=period)).strftime('%Y-%m-%d')
#     end_date = datetime.today().strftime('%Y-%m-%d')
#     data = yf.download(ticker, start=start_date, end=end_date)

#     data['Return'] = data['Adj Close'].pct_change()

#     return data['Return']


# def calculateTrackingError(stock, benchmark='^GSPC', period=30):
#     stockReturns = get_returns(stock, period)
#     benchmarkReturns = get_returns(benchmark, period)

#     excessReturns = stockReturns - benchmarkReturns

#     trackingError = np.std(excessReturns.dropna())

#     return trackingError


# stock = 'AAPL'
# # benchmark = '^GSPC'
# period = 30


# te = calculateTrackingError(stock, period=period)
# print(f"The Tracking Error is {te:.2%}")

# %%
dfRebalanced['Need Rebalance (Estratégico)'] = [True, True, False, True, False, False]
dfRebalanced['Need Rebalance (Tático)'] = [True, True, False, True, False, False]

dfRebalanced

# %% [markdown]
# ### Resultado Final:

# %%
alocacoes = ['Estratégico', 'Tático']

for alocacao in alocacoes:
    if dfRebalanced[f'Need Rebalance ({alocacao})'].any():
        print(f"Plano {alocacao}:\n")
        
        pValue = locale.format_string("%.3f", valorCarteira, grouping=True, monetary=True)
        print(f"[Portfolio Value]\n- {pValue}\n")
        
        for i in range(len(dfRebalanced)):
            if dfRebalanced[f'Offset ({alocacao})'][i] > 0:
                acao = 'Buy' 
            elif dfRebalanced[f'Offset ({alocacao})'][i] <  0:
                acao = 'Sell'
            else:
                acao = 'Skip'
    
            price = abs(valorCarteira * dfRebalanced[f'Offset ({alocacao})'][i])
            price = locale.format_string("%.3f", price, grouping=True, monetary=True)
            print(
f'''[{dfRebalanced['Alocação Estratégica por Mercado'][i]}]
- {acao} {price} of Porfolio Value ({abs(dfRebalanced[f'Offset ({alocacao})'][i]):.3%})
'''
            )

        print("\n")
